# %%
import numpy as np
sentences = np.array(["I like deep learning", "deep ´0.= love machine", "machine learning smile"])

# %%
x=np.round(np.random.rand(5,5)*10,0)
x
w = [[[1,1],[1,2]]]
s, = w
print(w,s)
np.max(w)
max=w-np.max(w)
max
# Out:
# [[[1, 1], [1, 2]]] [[1, 1], [1, 2]]
# array([[[-1, -1],
#         [-1,  0]]])
